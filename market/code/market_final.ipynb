# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Market.csv')

# %%
df = pd.DataFrame(data)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
df.describe(include='all')
# Out:
#          Index       Date           Open           High            Low  \
# count   112457     112457  110253.000000  110252.000000  110251.000000
# unique      14      14731            NaN            NaN            NaN
# top       N225  11/3/2017            NaN            NaN            NaN
# freq     14500         14            NaN            NaN            NaN
# mean       NaN        NaN    7658.561932    7704.538416    7608.129749
# std        NaN        NaN    9011.455529    9066.605458    8954.536718
# min        NaN        NaN      54.869999      54.869999      54.869999
# 25%        NaN        NaN    1855.060059    1864.687470    1844.015015
# 50%        NaN        NaN    5194.399902    5226.750000    5154.299805
# 75%        NaN        NaN   10134.299810   10207.827635   10060.369630
# max        NaN        NaN   68775.062500   69403.750000   68516.992190
#
#                 Close      Adj Close        Volume
# count   110250.000000  110244.000000  1.102530e+05
# ...

# %%
df2 = df.copy()

# %%
df2.drop(df2[df2['Index'] != 'NYA'].index, inplace=True)
df2
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
df2.describe(include='all')
# Out:
#         Index        Date          Open          High           Low  \
# count   13948       13948  13947.000000  13946.000000  13945.000000
# unique      1       13948           NaN           NaN           NaN
# top       NYA  12/31/1965           NaN           NaN           NaN
# freq    13948           1           NaN           NaN           NaN
# mean      NaN         NaN   4452.147406   4469.312526   4434.262223
# std       NaN         NaN   4074.835507   4094.956718   4052.815490
# min       NaN         NaN    347.769989    347.769989    347.769989
# 25%       NaN         NaN    654.989990    655.150024    655.039978
# 50%       NaN         NaN   2631.909912   2632.280029   2631.909912
# 75%       NaN         NaN   7339.489990   7376.315063   7277.509766
# max       NaN         NaN  16590.429690  16685.890630  16531.949220
#
#                Close     Adj Close        Volume
# count   13944.000000  13938.000000  1.394700e+04
# unique           NaN           NaN           NaN
# ...

# %%
df2.Date = pd.to_datetime(df2.Date)
df2 = df2.sort_values(by="Date")
df2
# Out:
#       Index       Date          Open          High           Low  \
# 0       NYA 1965-12-31    528.690002    528.690002    528.690002
# 1       NYA 1966-01-03    527.210022    527.210022    527.210022
# 2       NYA 1966-01-04    527.840027    527.840027    527.840027
# 3       NYA 1966-01-05    531.119995    531.119995    531.119995
# 4       NYA 1966-01-06    532.070007    532.070007    532.070007
# ...     ...        ...           ...           ...           ...
# 13943   NYA 2021-05-24  16375.000000  16508.519530  16375.000000
# 13944   NYA 2021-05-25  16464.689450  16525.810550  16375.150390
# 13945   NYA 2021-05-26  16390.189450  16466.339840  16388.320310
# 13946   NYA 2021-05-27  16451.960940  16546.359380  16451.960940
# 13947   NYA 2021-05-28  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
#plt.figure(dpi=800)
plt.title('Open market from 1965 to 2021', fontsize=20)
plt.scatter(df2['Date'], df2['Open'])
plt.xlabel('date', fontsize=15)
plt.ylabel('open', fontsize=15)
plt.grid()
#plt.savefig('date_open', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
df3 = df2[df2['Date'] <'1970'].copy()
df3.nlargest(5, columns='Open')
# Out:
#     Index       Date         Open        High         Low       Close  \
# 852   NYA 1969-06-30  5722.359985  572.359985  572.359985  572.359985
# 711   NYA 1968-11-29   647.849976  647.849976  647.849976  647.849976
# 712   NYA 1968-12-02   646.479980  646.479980  646.479980  646.479980
# 713   NYA 1968-12-03   645.950012  645.950012  645.950012  645.950012
# 715   NYA 1968-12-06   645.309998  645.309998  645.309998  645.309998
#
#       Adj Close  Volume
# 852  572.359985     0.0
# 711  647.849976     0.0
# 712  646.479980     0.0
# 713  645.950012     0.0
# 715  645.309998     0.0

# %%
#plt.figure(dpi=800)
plt.title('High market from 1965 to 2021', fontsize=20)
plt.scatter(df2['Date'], df2['High'])
plt.xlabel('date', fontsize=15)
plt.ylabel('high', fontsize=15)
plt.grid()
#plt.savefig('date_high', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
df4 = df2[df2['Date'] <'1970'].copy()
df4.nlargest(5, columns='High')
# Out:
#     Index       Date        Open         High         Low       Close  \
# 829   NYA 1969-05-27  612.219971  6124.219971  612.219971  612.219971
# 833   NYA 1969-06-03  606.830017  6065.830017  606.830017  606.830017
# 711   NYA 1968-11-29  647.849976   647.849976  647.849976  647.849976
# 712   NYA 1968-12-02  646.479980   646.479980  646.479980  646.479980
# 713   NYA 1968-12-03  645.950012   645.950012  645.950012  645.950012
#
#       Adj Close  Volume
# 829  612.219971     0.0
# 833  606.830017     0.0
# 711  647.849976     0.0
# 712  646.479980     0.0
# 713  645.950012     0.0

# %%
#plt.figure(dpi=800)
plt.title('Low market from 1965 to 2021', fontsize=20)
plt.scatter(df2['Date'], df2['Low'])
plt.xlabel('date', fontsize=15)
plt.ylabel('low', fontsize=15)
plt.grid()
#plt.savefig('date_low', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
#plt.figure(dpi=800)
plt.title('Close market from 1965 to 2021', fontsize=20)
plt.scatter(df2['Date'], df2['Close'])
plt.xlabel('date', fontsize=15)
plt.ylabel('close', fontsize=15)
plt.grid()
#plt.savefig('date_close', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
#plt.figure(dpi=800)
plt.title('Adj Close market from 1965 to 2021', fontsize=18)
plt.scatter(df2['Date'], df2['Adj Close'])
plt.xlabel('date', fontsize=15)
plt.ylabel('adj close', fontsize=15)
plt.grid()
#plt.savefig('date_adjclose', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
df5 = df2[df2['Date'] < '1975'].copy() 
df5.nlargest(5, columns='Adj Close')
# Out:
#      Index       Date        Open        High         Low       Close  \
# 831    NYA 1969-05-29  611.900024  611.900024  611.900024  611.900024
# 1745   NYA 1973-01-11  692.369995  692.369995  692.369995  692.369995
# 1741   NYA 1973-01-05  691.200012  691.200012  691.200012  691.200012
# 1742   NYA 1973-01-08  690.989990  690.989990  690.989990  690.989990
# 1739   NYA 1973-01-03  690.359985  690.359985  690.359985  690.359985
#
#         Adj Close  Volume
# 831   6110.900024     0.0
# 1745   692.369995     0.0
# 1741   691.200012     0.0
# 1742   690.989990     0.0
# 1739   690.359985     0.0

# %%
df2
# Out:
#       Index       Date          Open          High           Low  \
# 0       NYA 1965-12-31    528.690002    528.690002    528.690002
# 1       NYA 1966-01-03    527.210022    527.210022    527.210022
# 2       NYA 1966-01-04    527.840027    527.840027    527.840027
# 3       NYA 1966-01-05    531.119995    531.119995    531.119995
# 4       NYA 1966-01-06    532.070007    532.070007    532.070007
# ...     ...        ...           ...           ...           ...
# 13943   NYA 2021-05-24  16375.000000  16508.519530  16375.000000
# 13944   NYA 2021-05-25  16464.689450  16525.810550  16375.150390
# 13945   NYA 2021-05-26  16390.189450  16466.339840  16388.320310
# 13946   NYA 2021-05-27  16451.960940  16546.359380  16451.960940
# 13947   NYA 2021-05-28  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
df2.drop(852, inplace=True) #! Open column
df2
# Out:
#       Index       Date          Open          High           Low  \
# 0       NYA 1965-12-31    528.690002    528.690002    528.690002
# 1       NYA 1966-01-03    527.210022    527.210022    527.210022
# 2       NYA 1966-01-04    527.840027    527.840027    527.840027
# 3       NYA 1966-01-05    531.119995    531.119995    531.119995
# 4       NYA 1966-01-06    532.070007    532.070007    532.070007
# ...     ...        ...           ...           ...           ...
# 13943   NYA 2021-05-24  16375.000000  16508.519530  16375.000000
# 13944   NYA 2021-05-25  16464.689450  16525.810550  16375.150390
# 13945   NYA 2021-05-26  16390.189450  16466.339840  16388.320310
# 13946   NYA 2021-05-27  16451.960940  16546.359380  16451.960940
# 13947   NYA 2021-05-28  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
df2.drop(829, inplace=True) #! High column
df2.drop(833, inplace=True)
df2
# Out:
#       Index       Date          Open          High           Low  \
# 0       NYA 1965-12-31    528.690002    528.690002    528.690002
# 1       NYA 1966-01-03    527.210022    527.210022    527.210022
# 2       NYA 1966-01-04    527.840027    527.840027    527.840027
# 3       NYA 1966-01-05    531.119995    531.119995    531.119995
# 4       NYA 1966-01-06    532.070007    532.070007    532.070007
# ...     ...        ...           ...           ...           ...
# 13943   NYA 2021-05-24  16375.000000  16508.519530  16375.000000
# 13944   NYA 2021-05-25  16464.689450  16525.810550  16375.150390
# 13945   NYA 2021-05-26  16390.189450  16466.339840  16388.320310
# 13946   NYA 2021-05-27  16451.960940  16546.359380  16451.960940
# 13947   NYA 2021-05-28  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
df2.drop(831, inplace=True) #! Adj column
df2
# Out:
#       Index       Date          Open          High           Low  \
# 0       NYA 1965-12-31    528.690002    528.690002    528.690002
# 1       NYA 1966-01-03    527.210022    527.210022    527.210022
# 2       NYA 1966-01-04    527.840027    527.840027    527.840027
# 3       NYA 1966-01-05    531.119995    531.119995    531.119995
# 4       NYA 1966-01-06    532.070007    532.070007    532.070007
# ...     ...        ...           ...           ...           ...
# 13943   NYA 2021-05-24  16375.000000  16508.519530  16375.000000
# 13944   NYA 2021-05-25  16464.689450  16525.810550  16375.150390
# 13945   NYA 2021-05-26  16390.189450  16466.339840  16388.320310
# 13946   NYA 2021-05-27  16451.960940  16546.359380  16451.960940
# 13947   NYA 2021-05-28  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
df2.describe() #! bedone noise va ba missing values
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13943.000000  13942.000000  13941.000000  13940.000000  13934.000000
# mean    4452.882920   4469.635502   4435.362126   4454.131852   4455.806235
# std     4075.016076   4095.234524   4052.876577   4075.546081   4075.624383
# min      347.769989    347.769989    347.769989    347.769989    347.769989
# 25%      655.150024    655.230011    655.469971    655.544998    656.017487
# 50%     2632.120117   2632.280029   2632.439941   2632.439941   2633.704956
# 75%     7342.455078   7377.210083   7278.419922   7342.082519   7345.524902
# max    16590.429690  16685.890630  16531.949220  16590.429690  16590.429690
#
#              Volume
# count  1.394300e+04
# mean   1.215914e+09
# std    1.834302e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.682940e+09
# max    1.145623e+10

# %%
df2.isnull().sum()
# Out:
# Index         0
# Date          0
# Open          1
# High          2
# Low           3
# Close         4
# Adj Close    10
# Volume        1
# dtype: int64

# %%
for i in range(len(df2.index)):
    if df2.iloc[i].isnull().sum() >= 1:
        if df2.iloc[i].isnull().sum() == 1:
            print(f'there is {df2.iloc[i].isnull().sum()} missing value in row {i}')
        else:
            print(f'there are {df2.iloc[i].isnull().sum()} missing values in row {i}')
# Out:
# there is 1 missing value in row 102
# there is 1 missing value in row 104
# there is 1 missing value in row 154
# there is 1 missing value in row 170
# there is 1 missing value in row 190
# there is 1 missing value in row 231
# there is 1 missing value in row 257
# there is 1 missing value in row 282
# there are 6 missing values in row 289
# there is 1 missing value in row 307
# there is 1 missing value in row 333
# there is 1 missing value in row 353
# there is 1 missing value in row 464
# there is 1 missing value in row 635
# there is 1 missing value in row 700
# there is 1 missing value in row 800

# %%
df2 = df2.dropna()

# %%
df2.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13928.000000  13928.000000  13928.000000  13928.000000  13928.000000
# mean    4457.122309   4473.603377   4439.014504   4457.519410   4457.519410
# std     4075.160214   4095.378126   4053.002787   4075.665989   4075.665989
# min      347.769989    347.769989    347.769989    347.769989    347.769989
# 25%      656.419983    656.419983    656.419983    656.419983    656.419983
# 50%     2634.179931   2634.179931   2634.179931   2634.179931   2634.179931
# 75%     7350.584961   7385.307617   7282.672363   7348.750122   7348.750122
# max    16590.429690  16685.890630  16531.949220  16590.429690  16590.429690
#
#              Volume
# count  1.392800e+04
# mean   1.217224e+09
# std    1.834855e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.687250e+09
# max    1.145623e+10

# %%
df2.isnull().sum()
# Out:
# Index        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#plt.figure(dpi=800)
plt.title('High market from 1965 to 2021', fontsize=20)
plt.scatter(df2['Date'], df2['High'])
plt.xlabel('date', fontsize=15)
plt.ylabel('high', fontsize=15)
plt.grid()
plt.savefig('date_high_noise_cut', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
#plt.figure(dpi=800)
plt.title('Open market from 1965 to 2021', fontsize=20)
plt.scatter(df2['Date'], df2['Open'])
plt.xlabel('date', fontsize=15)
plt.ylabel('open', fontsize=15)
plt.grid()
plt.savefig('date_open_noise_cut', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
#plt.figure(dpi=800)
plt.title('Adj Close market from 1965 to 2021', fontsize=18)
plt.scatter(df2['Date'], df2['Adj Close'])
plt.xlabel('date', fontsize=15)
plt.ylabel('adj close', fontsize=15)
plt.grid()
plt.savefig('date_adjclose_noise_cut', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
plt.plot(df2['Date'].dt.year, df2['Adj Close'])
plt.xlabel('date', fontsize=15)
plt.ylabel('adj close', fontsize=15)
plt.grid()
plt.savefig('date_adjclose_plot_1', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
plt.plot(df2['Date'], df2['Adj Close'])
plt.xlabel('date', fontsize=15)
plt.ylabel('adj close', fontsize=15)
plt.grid()
plt.savefig('date_adjclose_plot_2', bbox_inches= 'tight', pad_inches=1)
plt.show()

# %%
df2
# Out:
#       Index       Date          Open          High           Low  \
# 0       NYA 1965-12-31    528.690002    528.690002    528.690002
# 1       NYA 1966-01-03    527.210022    527.210022    527.210022
# 2       NYA 1966-01-04    527.840027    527.840027    527.840027
# 3       NYA 1966-01-05    531.119995    531.119995    531.119995
# 4       NYA 1966-01-06    532.070007    532.070007    532.070007
# ...     ...        ...           ...           ...           ...
# 13943   NYA 2021-05-24  16375.000000  16508.519530  16375.000000
# 13944   NYA 2021-05-25  16464.689450  16525.810550  16375.150390
# 13945   NYA 2021-05-26  16390.189450  16466.339840  16388.320310
# 13946   NYA 2021-05-27  16451.960940  16546.359380  16451.960940
# 13947   NYA 2021-05-28  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
plt.title('five feature of Market', fontsize=20)
plt.plot(df2['Date'], df2['Open'], label='Open')
plt.plot(df2['Date'], df2['High'], label='High')
plt.plot(df2['Date'], df2['Low'], label='Low')
plt.plot(df2['Date'], df2['Close'], label='Close')
plt.plot(df2['Date'], df2['Adj Close'], label='Adj Close')
plt.xlabel('date', fontsize=15)
# plt.ylabel('date', fontsize=15)
plt.grid()
plt.legend()
plt.savefig('date_5feature', bbox_inches= 'tight', pad_inches=1, dpi=1200)
plt.show()

# %%
df2.to_csv('Market_final.csv')

# %%
 df2['Adj Close'] = df2['Adj Close'].astype(int)
# Out:
# /var/folders/0x/4j96rnd13md_8_5yl32pjc6w0000gn/T/ipykernel_681/3487110342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Adj Close'] = df2['Adj Close'].astype(int)

# %%
df2
# Out:
#       Index       Date          Open          High           Low  \
# 0       NYA 1965-12-31    528.690002    528.690002    528.690002
# 1       NYA 1966-01-03    527.210022    527.210022    527.210022
# 2       NYA 1966-01-04    527.840027    527.840027    527.840027
# 3       NYA 1966-01-05    531.119995    531.119995    531.119995
# 4       NYA 1966-01-06    532.070007    532.070007    532.070007
# ...     ...        ...           ...           ...           ...
# 13943   NYA 2021-05-24  16375.000000  16508.519530  16375.000000
# 13944   NYA 2021-05-25  16464.689450  16525.810550  16375.150390
# 13945   NYA 2021-05-26  16390.189450  16466.339840  16388.320310
# 13946   NYA 2021-05-27  16451.960940  16546.359380  16451.960940
# 13947   NYA 2021-05-28  16531.949220  16588.689450  16531.949220
#
#               Close  Adj Close        Volume
# 0        528.690002        528  0.000000e+00
# 1        527.210022        527  0.000000e+00
# 2        527.840027        527  0.000000e+00
# ...

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharey=True) #! rasme plot setaee kenare ham
axs[0].bar(df2['Date'], df2['Adj Close']) #! plot aval barplot
axs[0].grid() #! grid
fig.supylabel('Adj Close',fontsize=15) #! label gozari dar in plot fargh darad
axs[1].scatter(df2['Date'], df2['Adj Close']) #! rasme scatter plot
axs[1].grid() #! grid
fig.supxlabel('Date', fontsize=15) #! label gozari
axs[2].plot(df2['Date'], df2['Adj Close']) #! rasme plot
axs[2].grid() #! grid
fig.suptitle('price of market in 1965 to 2021', fontsize=20) #! title
plt.savefig('market-01', bbox_inches= 'tight', pad_inches=1) #! save
plt.show() #! show
