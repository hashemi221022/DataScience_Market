# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Market.csv') #! khandane file csv
data
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
df = pd.DataFrame(data)#! tabdile data be dataframe(df)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
df.describe() #! describe katrdan df
# Out:
#                 Open           High            Low          Close  \
# count  110253.000000  110252.000000  110251.000000  110250.000000
# mean     7658.561932    7704.538416    7608.129749    7657.740822
# std      9011.455529    9066.605458    8954.536718    9011.555549
# min        54.869999      54.869999      54.869999      54.869999
# 25%      1855.060059    1864.687469    1844.015015    1855.347473
# 50%      5194.399902    5226.750000    5154.299805    5194.889892
# 75%     10134.299810   10207.827635   10060.369630   10134.867430
# max     68775.062500   69403.750000   68516.992190   68775.062500
#
#            Adj Close        Volume
# count  110244.000000  1.102530e+05
# mean     7657.982529  1.273975e+09
# std      9011.723572  4.315783e+09
# min        54.869999  0.000000e+00
# 25%      1855.057556  0.000000e+00
# 50%      5195.699951  4.329000e+05
# 75%     10135.512452  1.734314e+08
# max     68775.062500  9.440374e+10

# %%
df2 = pd.DataFrame(data, columns=['Index', 'Adj Close']) #! joda kardan soton ya column ha da pandas
df2
# Out:
#        Index    Adj Close
# 0        NYA   528.690002
# 1        NYA   527.210022
# 2        NYA   527.840027
# 3        NYA   531.119995
# 4        NYA   532.070007
# ...      ...          ...
# 112452  N100  1247.069946
# 112453  N100  1256.599976
# 112454  N100  1248.930054
# 112455  N100  1258.579956
# 112456  N100  1263.619995
#
# [112457 rows x 2 columns]

# %%
df2.describe() #! describe kardane adj close
# Out:
#            Adj Close
# count  110244.000000
# mean     7657.982529
# std      9011.723572
# min        54.869999
# 25%      1855.057556
# 50%      5195.699951
# 75%     10135.512452
# max     68775.062500

# %%
df2.drop(df2[df2['Index'] != 'NYA'].index, inplace= True) #! joda kardan ye dade khas dar satrha
df2
# Out:
#       Index     Adj Close
# 0       NYA    528.690002
# 1       NYA    527.210022
# 2       NYA    527.840027
# 3       NYA    531.119995
# 4       NYA    532.070007
# ...     ...           ...
# 13943   NYA  16464.689450
# 13944   NYA  16390.189450
# 13945   NYA  16451.960940
# 13946   NYA  16531.949220
# 13947   NYA  16555.660160
#
# [13948 rows x 2 columns]

# %%
df2.describe(include='all') #! describ greftan az adad va horof ba ham
# Out:
#         Index     Adj Close
# count   13948  13938.000000
# unique      1           NaN
# top       NYA           NaN
# freq    13948           NaN
# mean      NaN   4455.094446
# std       NaN   4075.456765
# min       NaN    347.769989
# 25%       NaN    655.807525
# 50%       NaN   2633.015014
# 75%       NaN   7342.787598
# max       NaN  16590.429690

# %%
df3 = df2.dropna() #! hazfe nan ha az df
df3
# Out:
#       Index     Adj Close
# 0       NYA    528.690002
# 1       NYA    527.210022
# 2       NYA    527.840027
# 3       NYA    531.119995
# 4       NYA    532.070007
# ...     ...           ...
# 13943   NYA  16464.689450
# 13944   NYA  16390.189450
# 13945   NYA  16451.960940
# 13946   NYA  16531.949220
# 13947   NYA  16555.660160
#
# [13938 rows x 2 columns]

# %%
df3.describe(include='all') #! describe koli az df
# Out:
#         Index     Adj Close
# count   13938  13938.000000
# unique      1           NaN
# top       NYA           NaN
# freq    13938           NaN
# mean      NaN   4455.094446
# std       NaN   4075.456765
# min       NaN    347.769989
# 25%       NaN    655.807525
# 50%       NaN   2633.015014
# 75%       NaN   7342.787598
# max       NaN  16590.429690

# %%
plt.plot(df3['Index'], df3['Adj Close']) #! motmaen shodan az inke NYA faghat bar dasht shode

# %%
df.drop(df[df['Index'] != 'NYA'].index, inplace= True) #!bardasht satre delkhah az df
df
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
df.describe(include='all') #! describe koli az df
# Out:
#         Index        Date          Open          High           Low  \
# count   13948       13948  13947.000000  13946.000000  13945.000000
# unique      1       13948           NaN           NaN           NaN
# top       NYA  11/25/1986           NaN           NaN           NaN
# freq    13948           1           NaN           NaN           NaN
# mean      NaN         NaN   4452.147406   4469.312526   4434.262223
# std       NaN         NaN   4074.835507   4094.956718   4052.815490
# min       NaN         NaN    347.769989    347.769989    347.769989
# 25%       NaN         NaN    654.989990    655.150024    655.039978
# 50%       NaN         NaN   2631.909912   2632.280029   2631.909912
# 75%       NaN         NaN   7339.489990   7376.315063   7277.509766
# max       NaN         NaN  16590.429690  16685.890630  16531.949220
#
#                Close     Adj Close        Volume
# count   13944.000000  13938.000000  1.394700e+04
# unique           NaN           NaN           NaN
# ...

# %%
df4 = pd.DataFrame(data, columns=['Date', 'Adj Close']) #! joda kardane dota soton az kole df
df4
# Out:
#               Date    Adj Close
# 0       12/31/1965   528.690002
# 1         1/3/1966   527.210022
# 2         1/4/1966   527.840027
# 3         1/5/1966   531.119995
# 4         1/6/1966   532.070007
# ...            ...          ...
# 112452   5/27/2021  1247.069946
# 112453   5/28/2021  1256.599976
# 112454   5/31/2021  1248.930054
# 112455    6/1/2021  1258.579956
# 112456    6/2/2021  1263.619995
#
# [112457 rows x 2 columns]

# %%
df4.describe(include='all') #! describe koli az df4
# Out:
#              Date      Adj Close
# count      112457  110244.000000
# unique      14731            NaN
# top     3/16/2018            NaN
# freq           14            NaN
# mean          NaN    7657.982529
# std           NaN    9011.723572
# min           NaN      54.869999
# 25%           NaN    1855.057556
# 50%           NaN    5195.699951
# 75%           NaN   10135.512452
# max           NaN   68775.062500

# %%
#plt.scatter(df4['Date'], df4['Adj Close'])

# %%
#plt.plot(df4['Date'], df4['Adj Close'])

# %%
df5 = df4.dropna() #! hazf dade nan

# %%
df5.describe(include='all') #! describe be sorate koli
# Out:
#             Date      Adj Close
# count     110244  110244.000000
# unique     14656            NaN
# top     1/7/2014            NaN
# freq          14            NaN
# mean         NaN    7657.982529
# std          NaN    9011.723572
# min          NaN      54.869999
# 25%          NaN    1855.057556
# 50%          NaN    5195.699951
# 75%          NaN   10135.512452
# max          NaN   68775.062500

# %%
df5['Adj Close'] = df5['Adj Close'].astype(int) #! tabdile flot to int
df5
# Out:
# <ipython-input-24-395c10ec58a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['Adj Close'] = df5['Adj Close'].astype(int) #! tabdile flot to int
#               Date  Adj Close
# 0       12/31/1965        528
# 1         1/3/1966        527
# 2         1/4/1966        527
# 3         1/5/1966        531
# 4         1/6/1966        532
# ...            ...        ...
# 112452   5/27/2021       1247
# 112453   5/28/2021       1256
# 112454   5/31/2021       1248
# 112455    6/1/2021       1258
# 112456    6/2/2021       1263
#
# [110244 rows x 2 columns]

# %%
df5.Date = pd.to_datetime(df5.Date) #! tabdile date be year
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df5
# Out:
#              Date  Adj Close
# 0      1965-12-31        528
# 1      1966-01-03        527
# 2      1966-01-04        527
# 3      1966-01-05        531
# 4      1966-01-06        532
# ...           ...        ...
# 112452 2021-05-27       1247
# 112453 2021-05-28       1256
# 112454 2021-05-31       1248
# 112455 2021-06-01       1258
# 112456 2021-06-02       1263
#
# [110244 rows x 2 columns]

# %%
df5 = df5.sort_values(by="Date")

# %%
df5
# Out:
#              Date  Adj Close
# 92450  1965-01-05       1257
# 92451  1965-01-06       1263
# 92452  1965-01-07       1274
# 92453  1965-01-08       1286
# 92455  1965-01-12       1288
# ...           ...        ...
# 76222  2021-06-01       3221
# 58054  2021-06-02      14857
# 106948 2021-06-02      28946
# 112456 2021-06-02       1263
# 106949 2021-06-03      29058
#
# [110244 rows x 2 columns]

# %%
#plt.figure(figsize=(5,3), dpi=800) #! keyfiat va size koli nemodar
plt.title('price of market in 1965 t0 2021', fontsize=20) #! title
plt.plot(df5.Date, df5['Adj Close']) #! rasme plot
#plt.stem(Year, df5['Adj Close'])
plt.xlabel('DATE', fontsize=15) #! lebel x
plt.xticks(rotation=90) #! charkhesh 90 daraje
plt.ylabel('Adj Close', fontsize=15) #! lebel y
plt.grid() #! rasme grid
plt.savefig('market', bbox_inches= 'tight', pad_inches=1) #! save kardan plot
plt.show()

# %%
#plt.figure(figsize=(5,3), dpi=800) #! keyfiat va size koli nemodar
plt.title('price of market in 1965 t0 2021', fontsize=20) #! title
plt.plot(df5.Date.dt.year, df5['Adj Close']) #! rasme plot
#plt.stem(Year, df5['Adj Close'])
plt.xlabel('DATE', fontsize=15) #! lebel x
plt.xticks(rotation=90) #! charkhesh 90 daraje
plt.ylabel('Adj Close', fontsize=15) #! lebel y
plt.grid() #! rasme grid
plt.savefig('market', bbox_inches= 'tight', pad_inches=1) #! save kardan plot
plt.show()

# %%
# fig, axs = plt.subplots(1, 3, figsize=(12, 4), sharey=True) #! rasme plot setaee kenare ham
# axs[0].bar(Year, df5['Adj Close']) #! plot aval barplot
# axs[0].grid() #! grid
# fig.supylabel('Adj Close',fontsize=15) #! label gozari dar in plot fargh darad
# axs[1].scatter(Year, df5['Adj Close']) #! rasme scatter plot
# axs[1].grid() #! grid
# fig.supxlabel('Years', fontsize=15) #! label gozari
# axs[2].plot(Year, df5['Adj Close']) #! rasme plot
# axs[2].grid() #! grid
# fig.suptitle('price of market in 1965 to 2021', fontsize=20) #! title
# plt.savefig('market-02', bbox_inches= 'tight', pad_inches=1) #! save
# plt.show() #! show
